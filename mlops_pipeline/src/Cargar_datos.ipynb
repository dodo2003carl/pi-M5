# %% [markdown]
# # 1. Carga de Datos
# Este notebook realiza la carga inicial del dataset para el Proyecto Integrador.

# %%
import pandas as pd
import os

# Ruta al archivo Excel
data_path = '../Base_de_datos.xlsx'

try:
    df = pd.read_excel(data_path)
    print(f"Carga exitosa. Registros: {df.shape[0]}, Columnas: {df.shape[1]}")
    display(df.head())
except Exception as e:
    print(f"Error al cargar: {e}")
# Out:
# Error al cargar: [Errno 2] No such file or directory: '../Base_de_datos.xlsx'
